# %%
from main import test_compact

src_cmpt, cmpt_index = test_compact()

# %%
src_cmpt
# Out:
# [{'nameNarration': 'かごめ',
#   'progressNarration': '[textBlack:今、神浜にあったいくつかのグループが]@[textBlack:“][textRed:大きくふたつに分かれよう][textBlack:”としている。]'},
#  {'progressNarration': '[textBlack:それは、各グループの目的や]@[textBlack:魔法少女としての在り方がぶつかり合った]@[textYellow:キモチ][textBlack:の石を巡る争いが、]@[textBlack:大きな局面を迎えたということ。]'},
#  {'progressNarration': '[textBlack:だけど、魔法少女たちもみんな]@[textBlack:心と体をすり減らしながらも]@[textBlack:すぐにまた次の争いを始めることになると思う。]'},
#  {'progressNarration': '[textBlack:だから、この凪いでいる時間に、]@[textBlack:あの時からの出来事を振り返ろうと思う。]'},
#  {'progressNarration': '[textBlack:そう…完全に引き金が引かれたのは、]@[textBlack:ひとりの魔法少女の死だった。]'},
#  {'nameNarration': '牧野 郁美', 'narration': '―郁美―@令ちゃん！'},
#  {'nameNarration': 'かごめ',
#   'progressNarration': '[textBlack:あの時を皮切りに、]@[textYellow:キモチ][textBlack:の石を巡る争いの炎は燃え上がって、]@[textBlack:誰もが引き返せなくなってしまった。]'},
#  {'progressNarration': '[textBlack:今思えば、それを感じていたのは、]@[textYellow:キモチ][textBlack:も同じだったのかもしれない。]'},
#  {'nameNarration': 'うい',
# ...

# %%
import json
src_cmpt_full = {'items': src_cmpt}
src_cmpt_str = json.dumps(src_cmpt_full, ensure_ascii=False) # indent = 4 for pretty
with open('play.json','w', encoding='utf-8') as f:
    f.write(src_cmpt_str)

# %%
src_cmpt_str
# Out:
# '{\n    "items": [\n        {\n            "nameNarration": "かごめ",\n            "progressNarration": "[textBlack:今、神浜にあったいくつかのグループが]@[textBlack:“][textRed:大きくふたつに分かれよう][textBlack:”としている。]"\n        },\n        {\n            "progressNarration": "[textBlack:それは、各グループの目的や]@[textBlack:魔法少女としての在り方がぶつかり合った]@[textYellow:キモチ][textBlack:の石を巡る争いが、]@[textBlack:大きな局面を迎えたということ。]"\n        },\n        {\n            "progressNarration": "[textBlack:だけど、魔法少女たちもみんな]@[textBlack:心と体をすり減らしながらも]@[textBlack:すぐにまた次の争いを始めることになると思う。]"\n        },\n        {\n            "progressNarration": "[textBlack:だから、この凪いでいる時間に、]@[textBlack:あの時からの出来事を振り返ろうと思う。]"\n        },\n        {\n            "progressNarration": "[textBlack:そう…完全に引き金が引かれたのは、]@[textBlack:ひとりの魔法少女の死だった。]"\n        },\n        {\n            "nameNarration": "牧野 郁美",\n            "narration": "―郁美―@令ちゃん！"\n        },\n        {\n            "nameNarration": "かごめ",\n            "progressNarration": "[textBlack:あの時を皮切りに、]@[textYellow:キモチ][textBlack
# ...
